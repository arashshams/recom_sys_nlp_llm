# %%
#import
import os
import json

import numpy as np
import pandas as pd
from hashlib import sha1

from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from surprise import SVD
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate
from surprise import accuracy

# %%
data_offerings = pd.read_csv("data/offerings.csv")
data_reviews = pd.read_csv("data/reviews.csv")

# %%
data_offerings.head()
# Out:
#    hotel_class  region_id                                                url  \
# 0          4.0      60763  http://www.tripadvisor.com/Hotel_Review-g60763...
# 1          5.0      32655  http://www.tripadvisor.com/Hotel_Review-g32655...
# 2          3.5      60763  http://www.tripadvisor.com/Hotel_Review-g60763...
# 3          4.0      60763  http://www.tripadvisor.com/Hotel_Review-g60763...
# 4          4.0      60763  http://www.tripadvisor.com/Hotel_Review-g60763...
#
#    phone  details                                            address   type  \
# 0    NaN      NaN  {'region': 'NY', 'street-address': '147 West 4...  hotel
# 1    NaN      NaN  {'region': 'CA', 'street-address': '300 S Dohe...  hotel
# 2    NaN      NaN  {'region': 'NY', 'street-address': '790 Eighth...  hotel
# 3    NaN      NaN  {'region': 'NY', 'street-address': '152 West 5...  hotel
# 4    NaN      NaN  {'region': 'NY', 'street-address': '130 West 4...  hotel
#
#        id                                             name
# 0  113317                    Casablanca Hotel Times Square
# 1   76049  Four Seasons Hotel Los Angeles at Beverly Hills
# 2   99352                   Hilton Garden Inn Times Square
# 3   93589                           The Michelangelo Hotel
# 4  217616                          The Muse Hotel New York

# %%
data_reviews.head()
# Out:
#                                              ratings  \
# 0  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 1  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 2  {'service': 4.0, 'cleanliness': 5.0, 'overall'...
# 3  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 4  {'service': 4.0, 'cleanliness': 5.0, 'overall'...
#
#                                              title  \
# 0        “Truly is "Jewel of the Upper Wets Side"”
# 1                        “My home away from home!”
# 2                                     “Great Stay”
# 3                             “Modern Convenience”
# 4  “Its the best of the Andaz Brand in the US....”
#
#                                                 text  \
# 0  Stayed in a king suite for 11 nights and yes i...
# 1  On every visit to NYC, the Hotel Beacon is the...
# 2  This is a great property in Midtown. We two di...
# 3  The Andaz is a nice hotel in a central locatio...
# 4  I have stayed at each of the US Andaz properti...
#
#                                               author    date_stayed  \
# 0  {'username': 'Papa_Panda', 'num_cities': 22, '...  December 2012
# 1  {'username': 'Maureen V', 'num_reviews': 2, 'n...  December 2012
# 2  {'username': 'vuguru', 'num_cities': 12, 'num_...  December 2012
# 3  {'username': 'Hotel-Designer', 'num_cities': 5...    August 2012
# 4  {'username': 'JamesE339', 'num_cities': 34, 'n...  December 2012
#
#    offering_id  num_helpful_votes        date         id  via_mobile
# 0        93338                  0  2012-12-17  147643103       False
# 1        93338                  0  2012-12-17  147639004       False
# 2      1762573                  0  2012-12-18  147697954       False
# 3      1762573                  0  2012-12-17  147625723       False
# 4      1762573                  0  2012-12-17  147612823       False

# %%
# Merge datasets on the appropriate keys
merged_df = pd.merge(data_reviews, data_offerings, left_on='offering_id', right_on='id', how='inner')

merged_df = merged_df.rename(columns={'id_x': 'review_id', 'id_y': 'hotel_id'})

# Drop redundant columns
merged_df = merged_df.drop(columns=['offering_id']) 
merged_df.head()
# Out:
#                                              ratings  \
# 0  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 1  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 2  {'service': 4.0, 'cleanliness': 5.0, 'overall'...
# 3  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 4  {'service': 4.0, 'cleanliness': 5.0, 'overall'...
#
#                                              title  \
# 0        “Truly is "Jewel of the Upper Wets Side"”
# 1                        “My home away from home!”
# 2                                     “Great Stay”
# 3                             “Modern Convenience”
# 4  “Its the best of the Andaz Brand in the US....”
#
#                                                 text  \
# 0  Stayed in a king suite for 11 nights and yes i...
# 1  On every visit to NYC, the Hotel Beacon is the...
# 2  This is a great property in Midtown. We two di...
# 3  The Andaz is a nice hotel in a central locatio...
# 4  I have stayed at each of the US Andaz properti...
#
#                                               author    date_stayed  \
# 0  {'username': 'Papa_Panda', 'num_cities': 22, '...  December 2012
# 1  {'username': 'Maureen V', 'num_reviews': 2, 'n...  December 2012
# 2  {'username': 'vuguru', 'num_cities': 12, 'num_...  December 2012
# 3  {'username': 'Hotel-Designer', 'num_cities': 5...    August 2012
# 4  {'username': 'JamesE339', 'num_cities': 34, 'n...  December 2012
#
#    num_helpful_votes        date  review_id  via_mobile  hotel_class  \
# 0                  0  2012-12-17  147643103       False          3.0
# 1                  0  2012-12-17  147639004       False          3.0
# 2                  0  2012-12-18  147697954       False          4.0
# 3                  0  2012-12-17  147625723       False          4.0
# 4                  0  2012-12-17  147612823       False          4.0
#
#    region_id                                                url  phone  \
# 0      60763  http://www.tripadvisor.com/Hotel_Review-g60763...    NaN
# 1      60763  http://www.tripadvisor.com/Hotel_Review-g60763...    NaN
# 2      60763  http://www.tripadvisor.com/Hotel_Review-g60763...    NaN
# 3      60763  http://www.tripadvisor.com/Hotel_Review-g60763...    NaN
# 4      60763  http://www.tripadvisor.com/Hotel_Review-g60763...    NaN
#
#    details                                            address   type  \
# 0      NaN  {'region': 'NY', 'street-address': '2130 Broad...  hotel
# 1      NaN  {'region': 'NY', 'street-address': '2130 Broad...  hotel
# 2      NaN  {'region': 'NY', 'street-address': '485 5th Av...  hotel
# 3      NaN  {'region': 'NY', 'street-address': '485 5th Av...  hotel
# 4      NaN  {'region': 'NY', 'street-address': '485 5th Av...  hotel
#
#    hotel_id              name
# 0     93338      Hotel Beacon
# 1     93338      Hotel Beacon
# 2   1762573  Andaz 5th Avenue
# 3   1762573  Andaz 5th Avenue
# 4   1762573  Andaz 5th Avenue

# %%
# Safely parse 'details' and 'address' fields
def safe_json_parse(x, key):
    """Safely parse a JSON-like string and extract a specific key."""
    if isinstance(x, str):  # Only process strings
        try:
            data = json.loads(x.replace("'", '"'))  # Handle single quotes
            return data.get(key, None)  # Return the value for the given key
        except (json.JSONDecodeError, TypeError):
            return None
    return None

# Use the function to extract 'username' from 'author' column
merged_df['user_id'] = merged_df['author'].apply(lambda x: safe_json_parse(x, 'username'))

# Extract 'region' from 'details'
merged_df['region'] = merged_df['details'].apply(lambda x: safe_json_parse(x, 'region'))

# Extract 'street-address' from 'address'
merged_df['street_address'] = merged_df['address'].apply(lambda x: safe_json_parse(x, 'street-address'))

# Extract review date features
merged_df['review_year'] = pd.to_datetime(merged_df['date'], errors='coerce').dt.year
merged_df['review_month'] = pd.to_datetime(merged_df['date'], errors='coerce').dt.month

# %%
merged_df.head()
# Out:
#                                              ratings  \
# 0  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 1  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 2  {'service': 4.0, 'cleanliness': 5.0, 'overall'...
# 3  {'service': 5.0, 'cleanliness': 5.0, 'overall'...
# 4  {'service': 4.0, 'cleanliness': 5.0, 'overall'...
#
#                                              title  \
# 0        “Truly is "Jewel of the Upper Wets Side"”
# 1                        “My home away from home!”
# 2                                     “Great Stay”
# 3                             “Modern Convenience”
# 4  “Its the best of the Andaz Brand in the US....”
#
#                                                 text  \
# 0  Stayed in a king suite for 11 nights and yes i...
# 1  On every visit to NYC, the Hotel Beacon is the...
# 2  This is a great property in Midtown. We two di...
# 3  The Andaz is a nice hotel in a central locatio...
# 4  I have stayed at each of the US Andaz properti...
#
#                                               author    date_stayed  \
# 0  {'username': 'Papa_Panda', 'num_cities': 22, '...  December 2012
# 1  {'username': 'Maureen V', 'num_reviews': 2, 'n...  December 2012
# 2  {'username': 'vuguru', 'num_cities': 12, 'num_...  December 2012
# 3  {'username': 'Hotel-Designer', 'num_cities': 5...    August 2012
# 4  {'username': 'JamesE339', 'num_cities': 34, 'n...  December 2012
#
#    num_helpful_votes        date  review_id  via_mobile  hotel_class  ...  \
# 0                  0  2012-12-17  147643103       False          3.0  ...
# 1                  0  2012-12-17  147639004       False          3.0  ...
# 2                  0  2012-12-18  147697954       False          4.0  ...
# 3                  0  2012-12-17  147625723       False          4.0  ...
# 4                  0  2012-12-17  147612823       False          4.0  ...
#
#    details                                            address   type  \
# 0      NaN  {'region': 'NY', 'street-address': '2130 Broad...  hotel
# 1      NaN  {'region': 'NY', 'street-address': '2130 Broad...  hotel
# 2      NaN  {'region': 'NY', 'street-address': '485 5th Av...  hotel
# 3      NaN  {'region': 'NY', 'street-address': '485 5th Av...  hotel
# 4      NaN  {'region': 'NY', 'street-address': '485 5th Av...  hotel
#
#    hotel_id              name region                street_address  \
# 0     93338      Hotel Beacon   None  2130 Broadway at 75th Street
# 1     93338      Hotel Beacon   None  2130 Broadway at 75th Street
# 2   1762573  Andaz 5th Avenue   None                485 5th Avenue
# 3   1762573  Andaz 5th Avenue   None                485 5th Avenue
# 4   1762573  Andaz 5th Avenue   None                485 5th Avenue
#
#   review_year review_month         user_id
# 0        2012           12      Papa_Panda
# 1        2012           12       Maureen V
# 2        2012           12          vuguru
# 3        2012           12  Hotel-Designer
# 4        2012           12       JamesE339
#
# [5 rows x 23 columns]

# %%
merged_df.columns
# Out:
# Index(['ratings', 'title', 'text', 'author', 'date_stayed',
#        'num_helpful_votes', 'date', 'review_id', 'via_mobile', 'hotel_class',
#        'region_id', 'url', 'phone', 'details', 'address', 'type', 'hotel_id',
#        'name', 'region', 'street_address', 'review_year', 'review_month',
#        'user_id'],
#       dtype='object')

# %%
merged_df.nunique()
# Out:
# ratings               55523
# title                631300
# text                 877573
# author               577942
# date_stayed             168
# num_helpful_votes       100
# date                   3948
# review_id            878561
# via_mobile                2
# hotel_class               9
# region_id                25
# url                    3945
# phone                     0
# details                   0
# address                3937
# type                      1
# hotel_id               3945
# name                   3876
# region                    0
# street_address         3916
# review_year              12
# review_month             12
# user_id              536180
# dtype: int64

# %%
merged_df.isnull().sum()
# Out:
# ratings                   0
# title                     0
# text                      0
# author                    0
# date_stayed           67594
# num_helpful_votes         0
# date                      0
# review_id                 0
# via_mobile                0
# hotel_class           34937
# region_id                 0
# url                       0
# phone                878561
# details              878561
# address                   0
# type                      0
# hotel_id                  0
# name                      0
# region               878561
# street_address         6894
# review_year               0
# review_month              0
# user_id                1145
# dtype: int64

# %%
# Selected a subset with customers and products with at least 100 reviews
# Step 1: Filter customers with at least 100 reviews
customer_review_counts = merged_df.groupby('user_id').size().reset_index(name='review_count')
customers_with_at_least_100_reviews = customer_review_counts[customer_review_counts['review_count'] >= 100]

# Step 2: Filter products with at least 100 reviews
hotel_review_counts = merged_df.groupby('hotel_id').size().reset_index(name='review_count')
hotels_with_at_least_100_reviews = hotel_review_counts[hotel_review_counts['review_count'] >= 100]

# Step 3: Filter the original dataset to only include customers and products with at least 100 reviews
filtered_data = merged_df[
    (merged_df['user_id'].isin(customers_with_at_least_100_reviews['user_id'])) &
    (merged_df['hotel_id'].isin(hotels_with_at_least_100_reviews['hotel_id']))
]
filtered_data.shape
# Out:
# (71480, 23)

# %%
filtered_data.head()
# Out:
#                                                 ratings  \
# 1689                                   {'overall': 5.0}
# 1690                                   {'overall': 4.0}
# 1692                                   {'overall': 4.0}
# 1900                                   {'overall': 5.0}
# 3900  {'cleanliness': 5.0, 'value': 5.0, 'overall': ...
#
#                                                   title  \
# 1689                           “Lovely with HUGE rooms”
# 1690  “If you like traditional hotels, then you will...
# 1692            “See yourself at the Sherry-Netherland”
# 1900                                  “We will be back”
# 3900                                “Wonderful Hotel !”
#
#                                                    text  \
# 1689  I have stayed at the hotel twice. It is excell...
# 1690  We have just returned from our first trip to N...
# 1692  Many years ago, as a student and NYC taxi driv...
# 1900  Allt i toppskick. Verkligen ett toppenläge. En...
# 3900  The staff was very helpful and courteous. The ...
#
#                                           author date_stayed  \
# 1689  {'username': '', 'id': '', 'location': ''}         NaN
# 1690  {'username': '', 'id': '', 'location': ''}         NaN
# 1692  {'username': '', 'id': '', 'location': ''}         NaN
# 1900  {'username': '', 'id': '', 'location': ''}         NaN
# 3900  {'username': '', 'id': '', 'location': ''}  April 2006
#
#       num_helpful_votes        date  review_id  via_mobile  hotel_class  ...  \
# 1689                 15  2005-05-02    3431120       False          4.5  ...
# 1690                 15  2005-01-26    3087505       False          4.5  ...
# 1692                 20  2003-08-20    1237061       False          4.5  ...
# 1900                  0  2011-04-29  106447112       False          4.5  ...
# 3900                  0  2006-05-02    5028014       False          3.5  ...
#
#       details                                            address   type  \
# 1689      NaN  {'region': 'NY', 'street-address': '781 Fifth ...  hotel
# 1690      NaN  {'region': 'NY', 'street-address': '781 Fifth ...  hotel
# 1692      NaN  {'region': 'NY', 'street-address': '781 Fifth ...  hotel
# 1900      NaN  {'region': 'NY', 'street-address': '781 Fifth ...  hotel
# 3900      NaN  {'region': 'TX', 'street-address': '2900 Briar...  hotel
#
#       hotel_id                         name region      street_address  \
# 1689     93559  The Sherry-Netherland Hotel   None    781 Fifth Avenue
# 1690     93559  The Sherry-Netherland Hotel   None    781 Fifth Avenue
# 1692     93559  The Sherry-Netherland Hotel   None    781 Fifth Avenue
# 1900     93559  The Sherry-Netherland Hotel   None    781 Fifth Avenue
# 3900     98920   Houston Marriott Westchase   None  2900 Briarpark Dr.
#
#      review_year review_month user_id
# 1689        2005            5
# 1690        2005            1
# 1692        2003            8
# 1900        2011            4
# 3900        2006            5
#
# [5 rows x 23 columns]

# %%
yelp_business = pd.read_json("data/yelp/yelp_academic_dataset_business.json", lines=True)
yelp_reviews = pd.read_json("data/yelp/yelp_academic_dataset_review.json", lines = True)

# %%
yelp_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
yelp_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15

# %%
yelp_merged_df = pd.merge(yelp_business, yelp_reviews, on='business_id')

yelp_merged_df.head()
# Out:
#               business_id                      name                 address  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  1616 Chapala St, Ste 2
# 1  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  1616 Chapala St, Ste 2
# 2  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  1616 Chapala St, Ste 2
# 3  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  1616 Chapala St, Ste 2
# 4  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  1616 Chapala St, Ste 2
#
#             city state postal_code   latitude   longitude  stars_x  \
# 0  Santa Barbara    CA       93101  34.426679 -119.711197      5.0
# 1  Santa Barbara    CA       93101  34.426679 -119.711197      5.0
# 2  Santa Barbara    CA       93101  34.426679 -119.711197      5.0
# 3  Santa Barbara    CA       93101  34.426679 -119.711197      5.0
# 4  Santa Barbara    CA       93101  34.426679 -119.711197      5.0
#
#    review_count  ...                                         categories hours  \
# 0             7  ...  Doctors, Traditional Chinese Medicine, Naturop...  None
# 1             7  ...  Doctors, Traditional Chinese Medicine, Naturop...  None
# 2             7  ...  Doctors, Traditional Chinese Medicine, Naturop...  None
# 3             7  ...  Doctors, Traditional Chinese Medicine, Naturop...  None
# 4             7  ...  Doctors, Traditional Chinese Medicine, Naturop...  None
#
#                 review_id                 user_id stars_y useful  funny  cool  \
# 0  9vwYDBVI3ymdqcyJ5WW2Tg  e0imecnX_9MtLnS2rUZM-A       5      3      2     1
# 1  OXgg1LdxHDv3CBU5-xi2lA  _Q0fdLVoTnlNkEypUvNkHA       5      1      0     0
# 2  DG64cjud9cWB4fANskVxSw  ycUooVIDWPgXPf6niW-FWQ       4      2      0     0
# 3  hzvRRb40oPttxAdyr7kfow  CiwVvb7jWijWB5jkmatzKA       5      0      1     0
# 4  xUkBPk-QfcW4i3MRU5TeXw  QkCbMKBktkrkOFJugHvY6w       5      0      0     0
#
#                                                 text                date
# 0  I've had acupuncture treatments with Abby over... 2012-05-02 18:07:38
# 1  Abby is an amazing practitioner. In a treatmen... 2013-03-01 06:11:05
# 2  I went to see Abby for some digestive issues. ... 2013-01-17 00:05:43
# 3  Abby helped me with some longstanding issues, ... 2015-03-16 03:43:08
# 4  Recently, I referred a patient of mine with mu... 2013-03-05 18:45:07
#
# [5 rows x 22 columns]

# %%
restaurants_df = yelp_merged_df[yelp_merged_df['categories'].str.contains('Restaurant', case=False, na=False)]

print(f"Number of restaurants: {restaurants_df.shape[0]}")
# Out:
# Number of restaurants: 4724684

# %%
restaurants_df.head()
# Out:
#                business_id                name      address          city  \
# 46  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 47  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 48  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 49  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 50  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
#
#    state postal_code   latitude  longitude  stars_x  review_count  ...  \
# 46    PA       19107  39.955505 -75.155564      4.0            80  ...
# 47    PA       19107  39.955505 -75.155564      4.0            80  ...
# 48    PA       19107  39.955505 -75.155564      4.0            80  ...
# 49    PA       19107  39.955505 -75.155564      4.0            80  ...
# 50    PA       19107  39.955505 -75.155564      4.0            80  ...
#
#                                            categories  \
# 46  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 47  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 48  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 49  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 50  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
#
#                                                 hours               review_id  \
# 46  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  BXQcBN0iAi1lAUxibGLFzA
# 47  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  uduvUCvi9w3T2bSGivCfXg
# 48  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  a0vwPOqDXXZuJkbBW2356g
# 49  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  MKNp_CdR2k2202-c8GN5Dw
# 50  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  D1GisLDPe84Rrk_R4X2brQ
#
#                    user_id stars_y useful  funny  cool  \
# 46  6_SpY41LIHZuIaiDs5FMKA       4      0      0     1
# 47  tCXElwhzekJEH6QJe3xs7Q       4      3      1     2
# 48  WqfKtI-aGMmvbA9pPUxNQQ       5      0      0     0
# 49  3-1va0IQfK-9tUMzfHWfTA       5      5      0     5
# 50  EouCKoDfzaVG0klEgdDvCQ       4      2      1     1
#
#                                                  text                date
# 46  This is nice little Chinese bakery in the hear... 2014-05-26 01:09:53
# 47  This is the bakery I usually go to in Chinatow... 2013-10-05 15:19:06
# 48  A delightful find in Chinatown! Very clean, an... 2013-10-25 01:34:57
# 49  I ordered a graduation cake for my niece and i... 2018-05-20 17:58:57
# 50  HK-STYLE MILK TEA:  FOUR STARS\n\nNot quite su... 2013-10-25 02:31:35
#
# [5 rows x 22 columns]

# %%
# Selected a subset with customers and products with at least 100 reviews
# Step 1: Filter customers with at least 100 reviews
yelp_customer_review_counts = restaurants_df.groupby('user_id').size().reset_index(name='review_count')
yelp_customers_with_at_least_100_reviews = customer_review_counts[customer_review_counts['review_count'] >= 100]

# Step 2: Filter products with at least 100 reviews
yelp_review_counts = restaurants_df.groupby('business_id').size().reset_index(name='review_count')
yelp_with_at_least_100_reviews = hotel_review_counts[hotel_review_counts['review_count'] >= 100]

# Step 3: Filter the original dataset to only include customers and products with at least 100 reviews
yelp_filtered_data = restaurants_df[
    (restaurants_df['user_id'].isin(yelp_customers_with_at_least_100_reviews['user_id'])) &
    (restaurants_df['hotel_id'].isin(yelp_with_at_least_100_reviews['hotel_id']))
]
filtered_data.shape
